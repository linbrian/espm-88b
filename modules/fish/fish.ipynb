# %%
import math
import datascience as ds
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plots

# %%
def ricker(x, r = 1, K = 100):
    return x * math.exp(r * (1 - x / K))

ricker(110, r = 4, K = 100)
# Out:
# 73.7352050639203

# %%
T = 50
x = [0] * T
x[0] = 50 # Initial population size

## Simulate the Ricker model
for t in range(0,T-1):
    x[t+1] = ricker(x[t], 2.75, 100)

## Organize results as a Table object
data = Table([range(0,T),x], ["time", "x"])
data
# Out:
# time | x
# 0    | 50
# 1    | 197.754
# 2    | 13.4475
# 3    | 145.327
# 4    | 41.7832
# 5    | 207.153
# 6    | 10.8781
# 7    | 126.167
# 8    | 61.4371
# 9    | 177.415
# ... (40 rows omitted)

# %%
plots.plot(data["time"], data["x"])
